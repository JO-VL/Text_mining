I have, myself, full confidence that if all do their duty, if nothing is neglected, and if the best arrangements are made, as they are being made, we shall prove ourselves once again able to defend our Island home, to ride out the storm of war, and to outlive the menace of tyranny, if necessary for years, if necessary alone. At any rate, that is what we are going to try to do. That is the resolve of His Majesty’s Government-every man of them. That is the will of Parliament and the nation. The British Empire and the French Republic, linked together in their cause and in their need, will defend to the death their native soil, aiding each other like good comrades to the utmost of their strength. Even though large tracts of Europe and many old and famous States have fallen or may fall into the grip of the Gestapo and all the odious apparatus of Nazi rule, we shall not flag or fail. We shall go on to the end, we shall fight in France, we shall fight on the seas and oceans, we shall fight with growing confidence and growing strength in the air, we shall defend our Island, whatever the cost may be, we shall fight on the beaches, we shall fight on the landing grounds, we shall fight in the fields and in the streets, we shall fight in the hills; we shall never surrender, and even if, which I do not for a moment believe, this Island or a large part of it were subjugated and starving, then our Empire beyond the seas, armed and guarded by the British Fleet, would carry on the struggle, until, in God’s good time, the New World, with all its power and might, steps forth to the rescue and the liberation of the old.

'''

print(text)
# Out:
# The whole question of home defense against invasion is, of course, powerfully affected by the fact that we have for the time being in this Island incomparably more powerful military forces than we have ever had at any moment in this war or the last. But this will not continue. We shall not be content with a defensive war. We have our duty to our Ally. We have to reconstitute and build up the British Expeditionary Force once again, under its gallant Commander-in-Chief, Lord Gort. All this is in train; but in the interval we must put our defenses in this Island into such a high state of organization that the fewest possible numbers will be required to give effective security and that the largest possible potential of offensive effort may be realized. On this we are now engaged. It will be very convenient, if it be the desire of the House, to enter upon this subject in a secret Session. Not that the government would necessarily be able to reveal in very great detail military secrets, bu
# ...

# %%
# Tokenitzem el text

tokens = word_tokenize(text.lower())

# Ens quedem només amb els caràcters alfabètics per descartar tots els signes de puntuació

tokens = [token for token in tokens if token.isalpha()]

print(tokens)
# Out:
# ['the', 'whole', 'question', 'of', 'home', 'defense', 'against', 'invasion', 'is', 'of', 'course', 'powerfully', 'affected', 'by', 'the', 'fact', 'that', 'we', 'have', 'for', 'the', 'time', 'being', 'in', 'this', 'island', 'incomparably', 'more', 'powerful', 'military', 'forces', 'than', 'we', 'have', 'ever', 'had', 'at', 'any', 'moment', 'in', 'this', 'war', 'or', 'the', 'last', 'but', 'this', 'will', 'not', 'continue', 'we', 'shall', 'not', 'be', 'content', 'with', 'a', 'defensive', 'war', 'we', 'have', 'our', 'duty', 'to', 'our', 'ally', 'we', 'have', 'to', 'reconstitute', 'and', 'build', 'up', 'the', 'british', 'expeditionary', 'force', 'once', 'again', 'under', 'its', 'gallant', 'lord', 'gort', 'all', 'this', 'is', 'in', 'train', 'but', 'in', 'the', 'interval', 'we', 'must', 'put', 'our', 'defenses', 'in', 'this', 'island', 'into', 'such', 'a', 'high', 'state', 'of', 'organization', 'that', 'the', 'fewest', 'possible', 'numbers', 'will', 'be', 'required', 'to', 'give', 'effectiv
# ...

# %%
# Calculem la freqüència de paraules

from nltk.probability import FreqDist

freq = FreqDist(tokens)

# 10 paraules que més apareixen

freq.tabulate(10)
# Out:
#   the    of   and    we    to    in  that    be shall  have
#    72    33    33    32    25    19    17    15    14    12

# %%
# Comptem quantes paraules de les 10 més utilitzades són stopwords

top10 = freq.most_common(10)
stopwords_count = 0
for word, count in top10:
    if word.lower() in stopwords.words('english'):
        stopwords_count += 1

print(f'De les 10 paraules més freqüents, {stopwords_count} són stopwords.')
# Out:
# De les 10 paraules més freqüents, 9 són stopwords.

# %%
# Representació gràfica de la freqüència de paraules incloses les stopwords

sns.set_style('darkgrid')
freq.plot(20);

# %% [markdown]
# Com era d'esperar, l'article "the", que tant es fa servir pel masculí com pel femení, és la paraula més utilitzada amb molta diferència, seguida de "of" i "and". Per això és tant important eliminar les stopwords.

# %% [markdown]
# # Exercici 2
# ### Treu les stopwords i realitza stemming al teu conjunt de dades.

# %%
# Traiem les stopwords

filtered_tokens = [token for token in tokens if token not in stopwords.words('english')]

print(filtered_tokens)
# Out:
# ['whole', 'question', 'home', 'defense', 'invasion', 'course', 'powerfully', 'affected', 'fact', 'time', 'island', 'incomparably', 'powerful', 'military', 'forces', 'ever', 'moment', 'war', 'last', 'continue', 'shall', 'content', 'defensive', 'war', 'duty', 'ally', 'reconstitute', 'build', 'british', 'expeditionary', 'force', 'gallant', 'lord', 'gort', 'train', 'interval', 'must', 'put', 'defenses', 'island', 'high', 'state', 'organization', 'fewest', 'possible', 'numbers', 'required', 'give', 'effective', 'security', 'largest', 'possible', 'potential', 'offensive', 'effort', 'may', 'realized', 'engaged', 'convenient', 'desire', 'house', 'enter', 'upon', 'subject', 'secret', 'session', 'government', 'would', 'necessarily', 'able', 'reveal', 'great', 'detail', 'military', 'secrets', 'like', 'discussions', 'free', 'without', 'restraint', 'imposed', 'fact', 'read', 'next', 'day', 'enemy', 'government', 'would', 'benefit', 'views', 'freely', 'expressed', 'parts', 'house', 'members', 'kno
# ...

# %%
# Realitzem stemming

lemmatizer = WordNetLemmatizer()

lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

print(lemmatized_tokens)
# Out:
# ['whole', 'question', 'home', 'defense', 'invasion', 'course', 'powerfully', 'affected', 'fact', 'time', 'island', 'incomparably', 'powerful', 'military', 'force', 'ever', 'moment', 'war', 'last', 'continue', 'shall', 'content', 'defensive', 'war', 'duty', 'ally', 'reconstitute', 'build', 'british', 'expeditionary', 'force', 'gallant', 'lord', 'gort', 'train', 'interval', 'must', 'put', 'defense', 'island', 'high', 'state', 'organization', 'fewest', 'possible', 'number', 'required', 'give', 'effective', 'security', 'largest', 'possible', 'potential', 'offensive', 'effort', 'may', 'realized', 'engaged', 'convenient', 'desire', 'house', 'enter', 'upon', 'subject', 'secret', 'session', 'government', 'would', 'necessarily', 'able', 'reveal', 'great', 'detail', 'military', 'secret', 'like', 'discussion', 'free', 'without', 'restraint', 'imposed', 'fact', 'read', 'next', 'day', 'enemy', 'government', 'would', 'benefit', 'view', 'freely', 'expressed', 'part', 'house', 'member', 'knowledge',
# ...

# %%
# Calculem novament la freqüència de paraules sense tenir en compte les stopwords

freq_sense_stopwords = FreqDist(lemmatized_tokens)

# 10 paraules que més apareixen

freq_sense_stopwords.tabulate(10)
# Out:
#   shall   fight   would    time  island     may    many   power     war british
#      14       7       6       5       5       5       5       5       4       4

# %%
# Representació gràfica de la freqüència de paraules sense incloure les stopwords

sns.set_style('darkgrid')
freq_sense_stopwords.plot(20);

# %% [markdown]
# Podem veure que després de "shall" (paraula neutra), la més mencionada és "fight". Només sabent això i sense saber res del text, ja ens podriem imaginar que es tracta d'un text bèlic o reivindicatiu.

# %% [markdown]
# # Exercici 3
# ### Realitza sentiment analysis al teu conjunt de dades.

# %%
text_definitiu = ' '.join(lemmatized_tokens)

analyzer = SentimentIntensityAnalyzer()

scores = analyzer.polarity_scores(text_definitiu)

print(scores)
# Out:
# {'neg': 0.186, 'neu': 0.582, 'pos': 0.231, 'compound': 0.9599}

# %% [markdown]
# El text és majoritàriament neutral, però ens apareix un compound alt (0.96), el que indica que el text té un sentiment predominantment positiu.

# %%
# Analitzem cada frase

from nltk.tokenize import sent_tokenize

frases = sent_tokenize(text)

for frase in frases:
    # Tokenizem la frase en paraules
    words = word_tokenize(frase)

    # Eliminem les stopwords
    words = [word for word in words if word.lower() not in stopwords.words('english')]

    # Unim les paraules novament en una frase
    frase_processada = ' '.join(words)

    # Apliquem l'anàlisi de sentiment a la frase
    scores = analyzer.polarity_scores(frase_processada)
  
    print(frase)
    print(scores['compound'])
    print("---")
# Out:
# The whole question of home defense against invasion is, of course, powerfully affected by the fact that we have for the time being in this Island incomparably more powerful military forces than we have ever had at any moment in this war or the last.
# -0.296
# ---
# But this will not continue.
# 0.0
# ---
# We shall not be content with a defensive war.
# -0.5859
# ---
# We have our duty to our Ally.
# 0.0
# ---
# We have to reconstitute and build up the British Expeditionary Force once again, under its gallant Commander-in-Chief, Lord Gort.
# 0.4019
# ---
# All this is in train; but in the interval we must put our defenses in this Island into such a high state of organization that the fewest possible numbers will be required to give effective security and that the largest possible potential of offensive effort may be realized.
# 0.4939
# ---
# On this we are now engaged.
# 0.4019
# ---
# ...

# %%
positiu = sum(1 for frase in frases if analyzer.polarity_scores(' '.join(word_tokenize(frase)))['compound'] >= 0.1)
negatiu = sum(1 for frase in frases if analyzer.polarity_scores(' '.join(word_tokenize(frase)))['compound'] <= -0.1)
neutre = len(frases) - positiu - negatiu

print(f'Hi ha {positiu} frases amb sentiment positiu, {negatiu} frases amb sentiment negatiu i {neutre} frases neutres.')
# Out:
# Hi ha 14 frases amb sentiment positiu, 8 frases amb sentiment negatiu i 8 frases neutres.
